# %% [markdown]
# # My First Kaggle Notebook
#
# A simple machine learning practice notebook.

# %%
import pandas as pd
import numpy as np

print('Hello from my Kaggle notebook!')
print('GitHub + Kaggle practice')
